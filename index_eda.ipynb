# %%
import h5py
import pickle

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/splade

# %%
f = h5py.File('experiments/index-baseline/index/array_index.h5py', 'r')

# %%
len(f.keys())
# Out:
# 29961

# %%
f['dim'][()]
# Out:
# 14980

# %%
len(f['index_doc_id_1030'][:])
# Out:
# 662

# %%
f['index_doc_value_1030'][:]
# Out:
# array([8.15551937e-01, 1.03376317e+00, 1.65623084e-01, 1.27469230e+00,
#        7.89330184e-01, 1.36993301e+00, 2.43824467e-01, 8.26426804e-01,
#        1.78710330e+00, 8.89280140e-01, 1.47156298e+00, 8.45773697e-01,
#        3.72854650e-01, 1.14835572e+00, 1.89362264e+00, 1.48554862e+00,
#        4.27092999e-01, 1.67964339e+00, 5.56008339e-01, 8.03921878e-01,
#        8.03921878e-01, 1.28300916e-02, 8.30697238e-01, 2.70649165e-01,
#        1.45694339e+00, 1.14625528e-01, 1.26606691e+00, 3.66970152e-01,
#        1.52499294e+00, 7.87697732e-01, 8.92679095e-01, 1.10358047e+00,
#        6.95409954e-01, 8.40700030e-01, 6.24842465e-01, 9.82943296e-01,
#        1.80317545e+00, 6.31570637e-01, 1.27430081e+00, 1.26849699e+00,
#        9.58354831e-01, 1.43777883e+00, 1.11705594e-01, 1.76689923e-01,
#        2.98950076e-01, 6.74503371e-02, 6.74219966e-01, 9.04423833e-01,
#        7.60150282e-03, 7.91222274e-01, 3.22511435e-01, 1.43559134e+00,
# ...

# %%
[k for k in list(f.keys()) if 'index_doc' not in k]
# Out:
# ['dim']

# %%
import pickle


with open('experiments/toy/index/doc_ids.pkl', 'rb') as pf:
    data = pickle.load(pf)

# %%
len(data) ## These would be the passage IDs that correspond to doc IDs in toy_data/full_collection/raw.tsv
# Out:
# 5000

# %%
int(80/ 25)
# Out:
# 3

# %%
f['index_doc_id_4108'][:]
# Out:
# array([  24,   54,   55,   56,   73,   74,   75,  147,  169,  400,  409,
#         580,  581,  596,  641,  671,  771,  773,  774,  775,  776,  777,
#         786,  835,  853,  890,  916,  921,  987,  988, 1005, 1216, 1345,
#        1433, 1444, 1545, 1593, 1609, 1610, 1659, 1682, 1683, 1684, 1742,
#        1786, 1787, 1794, 1811, 1820, 1866, 1869, 1908, 2092, 2149, 2190,
#        2203, 2204, 2208, 2226, 2228, 2229, 2304, 2326, 2370, 2386, 2459,
#        2460, 2461, 2544, 2545, 2563, 2631, 2660, 2661, 2851, 2868, 2877,
#        2886, 3007, 3312, 3542, 3666, 3674, 3684, 3772, 3773, 3855, 3860,
#        3915, 3916, 3922, 3941, 4147, 4253, 4261, 4376, 4403, 4417, 4483,
#        4484, 4485, 4504, 4524, 4525, 4547, 4550, 4626, 4641, 4642, 4647,
#        4653, 4655, 4657, 4664, 4708, 4861, 4865, 4900, 4965, 4975, 5010,
#        5012, 5013, 5024, 5026, 5042, 5063, 5064, 5224, 5230, 5239, 5240,
#        5269, 5270, 5331, 5332, 5370, 5400, 5407, 5511, 5535, 5614, 5628,
# ...

# %%
with open('experiments/index-baseline/index/doc_ids.pkl', 'rb') as pf:
    data = pickle.load(pf)
    
data
# Out:
# [0,
#  0,
#  83,
#  85,
#  320,
#  356,
#  363,
#  366,
#  395,
#  459,
#  460,
#  461,
#  462,
#  466,
#  545,
#  584,
#  642,
#  648,
#  705,
#  729,
#  782,
#  788,
#  791,
#  792,
#  817,
#  818,
#  823,
#  824,
#  825,
#  851,
#  860,
#  936,
#  957,
#  968,
#  1061,
#  1065,
#  1067,
#  1103,
#  1118,
#  1123,
#  1207,
#  1226,
#  1235,
#  1262,
#  1306,
#  1328,
#  1368,
#  1409,
#  1410,
#  1474,
#  1520,
#  1523,
#  1531,
#  1538,
#  1562,
#  1581,
#  1582,
#  1590,
#  1702,
#  1738,
#  1756,
#  1794,
#  1865,
#  1883,
#  1885,
#  1936,
#  1969,
#  2005,
#  2048,
#  2065,
#  2068,
#  2086,
#  2132,
#  2133,
#  2135,
#  2140,
#  2148,
#  2214,
#  2298,
#  2355,
#  2357,
#  2427,
#  2498,
#  2541,
#  2542,
#  2651,
#  2666,
#  2667,
#  2679,
#  2685,
#  2687,
#  2725,
#  2730,
#  2864,
#  2869,
#  2952,
#  2969,
#  2985,
#  2994,
#  3029,
#  3100,
#  3166,
#  3234,
#  3266,
#  3271,
#  3274,
#  3418,
#  3476,
#  3569,
#  3593,
#  3617,
#  3661,
#  3715,
#  3757,
#  3771,
# ...
